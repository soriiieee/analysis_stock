# %%
import os,sys,glob
sys.path.append("..")
from py.utils_002_update import *
# sys.path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# START...Now is -> 2021-09-17 16:04:13.875669
# START...Now is -> 2021-09-17 16:04:13.960704

# %%
#業界別の企業一覧検索
check_category(col="name33")
# Out:
# --------------- name33 ----------------------------------------
# ['水産・農林業' '-' '卸売業' '建設業' '非鉄金属' '鉱業' 'サービス業' '機械' '金属製品' '情報・通信業' '食料品'
#  '医薬品' '不動産業' '陸運業' 'その他金融業' '小売業' 'その他製品' '繊維製品' '電気機器' 'ガラス・土石製品'
#  '証券、商品先物取引業' '輸送用機器' '石油・石炭製品' '化学' 'パルプ・紙' '精密機器' 'ゴム製品' '鉄鋼' '銀行業'
#  '保険業' '倉庫・運輸関連業' '海運業' '空運業' '電気・ガス業']
# ---------------
# 情報・通信業        518
# サービス業         503
# -             345
# 小売業           343
# 卸売業           317
# 電気機器          243
# 機械            230
# 化学            214
# 建設業           165
# 不動産業          142
# 食料品           125
# その他製品         112
# 輸送用機器          91
# 金属製品           90
# 銀行業            81
# 医薬品            72
# 陸運業            62
# ガラス・土石製品       56
# 繊維製品           51
# 精密機器           50
# 鉄鋼             43
# 証券、商品先物取引業     41
# 倉庫・運輸関連業       39
# 非鉄金属           36
# その他金融業         33
# 電気・ガス業         24
# パルプ・紙          24
# ゴム製品           19
# 保険業            15
# 海運業            13
# 水産・農林業         12
# 石油・石炭製品        11
# 鉱業              6
# 空運業             5
# Name: name33, dtype: int64

# %%
check_category(col="name17")
# Out:
# --------------- name17 ----------------------------------------
# ['食品 ' '-' '商社・卸売 ' '建設・資材 ' '鉄鋼・非鉄 ' 'エネルギー資源 ' '情報通信・サービスその他 ' '機械 '
#  '医薬品 ' '不動産 ' '運輸・物流 ' '金融（除く銀行） ' '小売 ' '素材・化学 ' '電機・精密 ' '自動車・輸送機 '
#  '銀行 ' '電力・ガス ']
# ---------------
# 情報通信・サービスその他     1133
# -                 345
# 小売                343
# 商社・卸売             317
# 建設・資材             311
# 電機・精密             293
# 素材・化学             289
# 機械                230
# 不動産               142
# 食品                137
# 運輸・物流             119
# 自動車・輸送機           110
# 金融（除く銀行）           89
# 銀行                 81
# 鉄鋼・非鉄              79
# 医薬品                72
# 電力・ガス              24
# エネルギー資源            17
# Name: name17, dtype: int64

# %%
col ,name= "name17","自動車・輸送機 "
# col ,name= "name33","輸送用機器"
#-dataSet Getting--
top30_get(col=col,name =name)
# Out:
# making Top 30 list ...
# 2021-09-17 16:05:41.238182 [END] 0 トヨタ自動車
# 2021-09-17 16:05:42.811182 [END] 1 本田技研工業
# 2021-09-17 16:05:44.331292 [END] 2 日産自動車
# 2021-09-17 16:05:45.774883 [END] 3 デンソー
# 2021-09-17 16:05:47.183789 [END] 4 アイシン
# 2021-09-17 16:05:48.583842 [END] 5 スズキ
# 2021-09-17 16:05:50.122552 [END] 6 マツダ
# 2021-09-17 16:05:51.636962 [END] 7 ＳＵＢＡＲＵ
# 2021-09-17 16:05:53.127972 [END] 8 ブリヂストン
# 2021-09-17 16:05:54.564798 [END] 9 豊田自動織機
# 2021-09-17 16:05:56.016346 [END] 10 いすゞ自動車
# 2021-09-17 16:05:57.566185 [END] 11 日野自動車
# 2021-09-17 16:05:59.016929 [END] 12 川崎重工業
# 2021-09-17 16:06:00.509266 [END] 13 ヤマハ発動機
# 2021-09-17 16:06:01.992729 [END] 14 三菱自動車工業
# 2021-09-17 16:06:03.479562 [END] 15 トヨタ紡織
# 2021-09-17 16:06:04.968710 [END] 16 住友ゴム工業
# 2021-09-17 16:06:06.477788 [END] 17 豊田合成
# 2021-09-17 16:06:07.845163 [END] 18 三井Ｅ＆Ｓホールディングス
# 2021-09-17 16:06:09.359041 [END] 19 ＮＯＫ
# 2021-09-17 16:06:10.915317 [END] 20 横浜ゴム
# 2021-09-17 16:06:12.450409 [END] 21 フタバ産業
# 2021-09-17 16:06:13.861302 [END] 22 東海理化電機製作所
# 2021-09-17 16:06:15.283163 [END] 23 住友理工
# 2021-09-17 16:06:16.786412 [END] 24 三菱ロジスネクスト
# 2021-09-17 16:06:18.336800 [END] 25 シマノ
# 2021-09-17 16:06:20.398316 [END] 26 日産車体
# 2021-09-17 16:06:21.862987 [END] 27 テイ・エス　テック
# 2021-09-17 16:06:23.235835 [END] 28 ＴＯＹＯ　ＴＩＲＥ
# 2021-09-17 16:06:24.669085 [END] 29 ＫＹＢ

# %%
# https://qiita.com/THERE2/items/3c13164c1c82c1dcf4b7
# FXの予測をpytorchのRNNで行ってみるというもの　->　時系列データの学習に使える可能性はあるのか検証を行う予定

col ,name= "name17","自動車・輸送機 "
DIR=f"/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/{col}/{name}"
_path = glob.glob(f"{DIR}/*.csv")
# _path

# %%
import numpy as np 
import pandas as pd 
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import pickle
from datetime import datetime
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import gc

import warnings
warnings.simplefilter('ignore')
# matplot で日本語
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.size'] = 18
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']

# %%
def load_df(path):
    df = pd.read_csv(path)
    if df["time"].dtypes==object:
        df["time"] = pd.to_datetime(df["time"])
#     sus.exit()
    df = df.set_index("time")
    return df

def plot(df,_col, title=None):
    f,ax = plt.subplots(figsize=(20,8))
    for c in _col:
        ax.plot(df[c], label=c)
    
    if title:
        ax.set_title(title)
    ax.legend()
    plt.show()
    return

def plot2(_df,_col,_title=None):
    f,ax = plt.subplots(figsize=(20,16))
    for i,df in enumerate(_df):
        for c in _col:
            if _title:
                label=f"{_title[i]}-{c}"
            else:
                label=c
            ax.plot(df[c], label=label)
    
#     if title:
#         ax.set_title(title)
    ax.legend()
    plt.show()
    return



def cut_time(df,st,ed=None):
    if not "time" in df.columns:
        df= df.reset_index()
    if df["time"].dtypes==object:
        df["time"] = pd.to_datetime(df["time"])
    
    if ed ==None:
        ed = datetime.now()
    df = df[(df["time"]>st)&(df["time"]<ed)]
    if "time" in df.columns:
        df = df.set_index("time")
    return df

#----------
_title = [ str(i).zfill(3) +" | "+ os.path.basename(p) for i,p in enumerate(_path)]
print(_title)

_df = []
for path in _path:
    df = load_df(path)
    df = cut_time(df, datetime(2021,5,1,0,0)) #時間のカット
#     title = os.path.basename(path)
    _df.append(df)
#     print(title)
#     sys.exit()
    
    
plot2(_df, _col=["close"],_title=_title)
# Out:
# ['000 | 7203_トヨタ自動車.csv', '001 | 7267_本田技研工業.csv', '002 | 7201_日産自動車.csv', '003 | 6902_デンソー.csv', '004 | 7259_アイシン.csv', '005 | 7269_スズキ.csv', '006 | 7261_マツダ.csv', '007 | 7270_ＳＵＢＡＲＵ.csv', '008 | 5108_ブリヂストン.csv', '009 | 6201_豊田自動織機.csv', '010 | 7202_いすゞ自動車.csv', '011 | 7205_日野自動車.csv', '012 | 7012_川崎重工業.csv', '013 | 7272_ヤマハ発動機.csv', '014 | 7211_三菱自動車工業.csv', '015 | 3116_トヨタ紡織.csv', '016 | 5110_住友ゴム工業.csv', '017 | 7282_豊田合成.csv', '018 | 7003_三井Ｅ＆Ｓホールディングス.csv', '019 | 7240_ＮＯＫ.csv', '020 | 5101_横浜ゴム.csv', '021 | 7241_フタバ産業.csv', '022 | 6995_東海理化電機製作所.csv', '023 | 5191_住友理工.csv', '024 | 7105_三菱ロジスネクスト.csv', '025 | 7309_シマノ.csv', '026 | 7222_日産車体.csv', '027 | 7313_テイ・エス\u3000テック.csv', '028 | 5105_ＴＯＹＯ\u3000ＴＩＲＥ.csv', '029 | 7242_ＫＹＢ.csv']
