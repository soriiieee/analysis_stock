# %%
import os,sys,glob
sys.path.append("..")
from py.utils_002_update import *
# sys.path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# log -> 
# """
# 2021.09.17 init
# 2021.09.22 second
# """
# Out:
# START...Now is -> 2021-09-22 18:47:55.248519
# START...Now is -> 2021-09-22 18:47:55.315060

# %%
#業界別の企業一覧検索
check_category(col="name17")
# Out:
# --------------- name17 ----------------------------------------
# ['食品 ' '-' '商社・卸売 ' '建設・資材 ' '鉄鋼・非鉄 ' 'エネルギー資源 ' '情報通信・サービスその他 ' '機械 '
#  '医薬品 ' '不動産 ' '運輸・物流 ' '金融（除く銀行） ' '小売 ' '素材・化学 ' '電機・精密 ' '自動車・輸送機 '
#  '銀行 ' '電力・ガス ']
# ---------------
# 情報通信・サービスその他     1133
# -                 345
# 小売                343
# 商社・卸売             317
# 建設・資材             311
# 電機・精密             293
# 素材・化学             289
# 機械                230
# 不動産               142
# 食品                137
# 運輸・物流             119
# 自動車・輸送機           110
# 金融（除く銀行）           89
# 銀行                 81
# 鉄鋼・非鉄              79
# 医薬品                72
# 電力・ガス              24
# エネルギー資源            17
# Name: name17, dtype: int64

# %%
check_category(col="name17")
# Out:
# --------------- name17 ----------------------------------------
# ['食品 ' '-' '商社・卸売 ' '建設・資材 ' '鉄鋼・非鉄 ' 'エネルギー資源 ' '情報通信・サービスその他 ' '機械 '
#  '医薬品 ' '不動産 ' '運輸・物流 ' '金融（除く銀行） ' '小売 ' '素材・化学 ' '電機・精密 ' '自動車・輸送機 '
#  '銀行 ' '電力・ガス ']
# ---------------
# 情報通信・サービスその他     1133
# -                 345
# 小売                343
# 商社・卸売             317
# 建設・資材             311
# 電機・精密             293
# 素材・化学             289
# 機械                230
# 不動産               142
# 食品                137
# 運輸・物流             119
# 自動車・輸送機           110
# 金融（除く銀行）           89
# 銀行                 81
# 鉄鋼・非鉄              79
# 医薬品                72
# 電力・ガス              24
# エネルギー資源            17
# Name: name17, dtype: int64

# %%
col ,name= "name17","自動車・輸送機 "
# col ,name= "name33","輸送用機器"
#-dataSet Getting--
top30_get(col=col,name =name,N=5)
# Out:
# 2021-09-22 18:47:56.112434 [END] 0 トヨタ自動車
# 2021-09-22 18:47:56.706381 [END] 1 本田技研工業
# 2021-09-22 18:48:02.547399 [END] 2 日産自動車
# 2021-09-22 18:48:03.155857 [END] 3 デンソー
# 2021-09-22 18:48:03.926492 [END] 4 アイシン
# outfile is -->
# ../out/ts1/name17/自動車・輸送機

# %%
# https://qiita.com/THERE2/items/3c13164c1c82c1dcf4b7
# FXの予測をpytorchのRNNで行ってみるというもの　->　時系列データの学習に使える可能性はあるのか検証を行う予定
# col ,name= "name17","自動車・輸送機 "
# # col ,name= "name33","輸送用機器"
# #-dataSet Getting--
# top30_get(col=col,name =name)
col ,name= "name17","自動車・輸送機 "
DIR=f"/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/{col}/{name}"
_path = glob.glob(f"{DIR}/*.csv")
# _path

# %%
import numpy as np 
import pandas as pd 
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import pickle
from datetime import datetime
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import gc

import warnings
warnings.simplefilter('ignore')
# matplot で日本語
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.size'] = 18
rcParams['font.sans-serif'] = ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']

# %%
def load_df(path):
    df = pd.read_csv(path)
    if df["time"].dtypes==object:
        df["time"] = pd.to_datetime(df["time"])
#     sus.exit()
    df = df.set_index("time")
    return df

def plot(df,_col, title=None):
    f,ax = plt.subplots(figsize=(20,8))
    for c in _col:
        ax.plot(df[c], label=c)
    
    if title:
        ax.set_title(title)
    ax.legend()
    plt.show()
    return

def plot2(_df,_col,_title=None,ylim=None):
    f,ax = plt.subplots(figsize=(20,16))
    for i,df in enumerate(_df):
        for c in _col:
            if _title:
                label=f"{_title[i]}-{c}"
            else:
                label=c
            ax.plot(df[c], label=label)
    
#     if title:
#         ax.set_title(title)
    if ylim:
        ax.set_ylim(*ylim)
    ax.legend()
    plt.show()
    return



def cut_time(df,st,ed=None):
    if not "time" in df.columns:
        df= df.reset_index()
    if df["time"].dtypes==object:
        df["time"] = pd.to_datetime(df["time"])
    
    if ed ==None:
        ed = datetime.now()
    df = df[(df["time"]>st)&(df["time"]<ed)]
    if "time" in df.columns:
        df = df.set_index("time")
    return df

def change_price(df):
    ini_p = df["close"].values[0]
    df["close"] /=ini_p
    return df

#----------
# _title = [ str(i).zfill(3) +" | "+ os.path.basename(p) for i,p in enumerate(_path)]
# print(_title)

# _df = []
# st = 
# for path in _path:
#     df = load_df(path)
#     df = cut_time(df, datetime(2021,9,1,0,0)) #時間のカット
#     df = change_price(df)
# #     title = os.path.basename(path)
#     _df.append(df)
# #     print(title)
# #     sys.exit()
    
    
# plot2(_df, _col=["close"],_title=_title, ylim=[0.5,2])

# %%
_path
# Out:
# ['/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7203_トヨタ自動車.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7267_本田技研工業.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7201_日産自動車.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /6902_デンソー.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7259_アイシン.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7269_スズキ.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7261_マツダ.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7270_ＳＵＢＡＲＵ.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /5108_ブリヂストン.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /6201_豊田自動織機.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7202_いすゞ自動車.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7205_日野自動車.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7012_川崎重工業.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7272_ヤマハ発動機.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7211_三菱自動車工業.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /3116_トヨタ紡織.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /5110_住友ゴム工業.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7282_豊田合成.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7003_三井Ｅ＆Ｓホールディングス.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7240_ＮＯＫ.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /5101_横浜ゴム.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7241_フタバ産業.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /6995_東海理化電機製作所.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /5191_住友理工.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7105_三菱ロジスネクスト.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7309_シマノ.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7222_日産車体.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7313_テイ・エス\u3000テック.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /5105_ＴＯＹＯ\u3000ＴＩＲＥ.csv',
#  '/home/ysorimachi/work/sori_py2/analysis_stock/out/ts1/name17/自動車・輸送機 /7242_ＫＹＢ.csv']

# %%
#scipy stats　の勉強　21.09.2
# https://kaisk.hatenadiary.com/entry/2015/02/17/192955

from scipy.stats import norm
import seaborn as sns
def main(size=100):
    x = norm.rvs(loc=0,scale=1,size=size)
    if type(x) != np.ndarray:
        x = np.array(x) 
    return x

def plot_scatter1(x, title="サンプル"):
    plt.figure(figsize=(18,8))
    plt.scatter(np.arange(len(x)),x)
    plt.title(title)
    plt.show()
    return


def plot_bins(x,title="sample"):
    f,ax = plt.subplots(figsize=(18,8))
    sns.histplot(x,ax=ax)
    plt.show()
    return

# %%
import matplotlib
from matplotlib import font_manager
# fontprop = matplotlib.font_manager.FontProperties(fname="/Library/Fonts/Osaka.ttf")
# ['Hiragino Maru Gothic Pro', 'Yu Gothic', 'Meirio', 'Takao', 'IPAexGothic', 'IPAPGothic', 'VL PGothic', 'Noto Sans CJK JP']
fontfamily = 'Hiragino Maru Gothic Pro'
fontfamily = 'IPAPGothic'
font = {"family": fontfamily}
matplotlib.rc('font', **font)

# %%
x = main(size=50000)
# plot_scatter1(x)
# plot_bins(x)

# %%
import statsmodels.api as sm
# from statsmodels.graphics.gofplots import qqplot
from scipy.stats import norm,gamma
# x = main(size=50)


def get_stock(keyword,st,ed=None):
    path = [ f for f in _path if keyword in f]
    if len(path)==0:
        sys.exit("No FILE !")
    else:
        path = path[0]
        pass
    df = load_df(path)
    df = cut_time(df,st=st, ed=ed)
    return df

df = get_stock("トヨタ自動車",st=datetime(2018,1,1,0,0),ed=None)
df.head()
# Out:
#               open   close    high     low  diff_max  diff_day     volume  \
# time
# 2018-01-02  7213.0  7213.0  7213.0  7213.0       0.0       0.0        0.0
# 2018-01-03  7213.0  7213.0  7213.0  7213.0       0.0       0.0        0.0
# 2018-01-04  7300.0  7413.0  7413.0  7293.0     120.0     113.0  9355400.0
# 2018-01-05  7450.0  7552.0  7555.0  7448.0     107.0     102.0  8616400.0
# 2018-01-08  7552.0  7552.0  7552.0  7552.0       0.0       0.0        0.0
#
#             log_diff
# time
# 2018-01-02    0.0000
# 2018-01-03    0.0000
# 2018-01-04    0.0274
# 2018-01-05    0.0186
# 2018-01-08    0.0000

# %%
plot_scatter1(df["log_diff"])

# %%
plot_bins(df["log_diff"])

# %%
sm.qqplot(df["log_diff"])

# %%
# https://office54.net/python/module/pykakasi-kanji-convert
import pykakasi
def convert_roma(word):
    kks = pykakasi.kakasi()
    result = kks.convert(word)
    return result[0]['hepburn']
# convert_roma("トヨタ自動車")
# Out:
# 'toyota'

# %%
def tmp(keyword,yy,col="log_diff"):
#     yy=2018
    df = get_stock(keyword,st=datetime(yy,1,1,0,0),ed=datetime(yy+2,1,1,0,0))
    print("N=",df.shape)
    print("Columns= ", df.columns)
#     sm.qqplot(df[col])
    title = convert_roma(keyword)
    plot(df,_col=[col], title=title)
    return
tmp("トヨタ自動車",yy=2019, col="log_diff")
# Out:
# N= (483, 8)
# Columns=  Index(['open', 'close', 'high', 'low', 'diff_max', 'diff_day', 'volume',
#        'log_diff'],
#       dtype='object')

# %%
def plot_multi(_df,c,_title=None):
    f,ax = plt.subplots(figsize=(20,15))
    for j,df in enumerate(_df):
        if _title:
            label=_title[j]
        else:
            label="sample"
        ax.plot(df[c], label=label)
    
#     ax.legend()
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.title(c)
    plt.show()
    return

def plot_vola(_df,c,_title=None, isPrint=False):
    f,ax = plt.subplots(figsize=(20,8))
    
    _df2=[]
    for j,(df,title) in enumerate(zip(_df,_title)):
        df["com"] = title
        _df2.append(df)
        
        if isPrint:  
            mu = np.round(np.mean(df[c]),3)
            std = np.round(np.std(df[c]),3)
            print(title,f"-> mu = {mu} | std = {std}")
    
    df = pd.concat(_df2, axis=0)
    
    ax = sns.boxplot(x="com", y=c, data=df,ax=ax)
#     ax.legend()
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
    plt.show()
    return

def plot_corr(_df,c,_title=None):
    _df2=[]
    f,ax = plt.subplots(figsize=(20,20))
    for j,(df,title) in enumerate(zip(_df,_title)):
#         s = df[c]
        df.index.name = "time"
        lbl = f"{j}_{title}"
        df =df.rename(columns={c: lbl})
        s = df[lbl]
        _df2.append(s)
    
    df = pd.concat(_df2,axis=1)
    corr = df.corr()
    if 0:
        _index = corr.index
        _columns = corr.columns
        corr = np.where(corr.values>0.7,1,0)
        corr = pd.DataFrame(corr,index=_index,columns=_columns)
    sns.heatmap(corr,annot=True,ax=ax, cmap="seismic",vmin=-1,vmax=1)
#     ax = sns.pairplot(df,ax=ax)
    plt.show()
    return

# %%
from scipy.stats import shapiro

def plot_shapiro(_df,c,_title,isPrint=False):
    f,ax = plt.subplots(figsize=(20,8))
    
    _df2=[]
    _w,_p=[],[]
    for j,(df,title) in enumerate(zip(_df,_title)):
        
        W,p = shapiro(df[c])
        _w.append(W)
        _p.append(p)
        
        if isPrint:  
            mu = np.round(W,3)
            std = np.round(p,3)
            print(title,f"-> W = {W} | p-values = {p}")
            
#     ax.legend()
    ax.bar(np.arange(len(_df)), _p)
    ax.set_xlim(0,len(_df))
    ax.set_xticks(np.arange(len(_df)))
    ax.set_xticklabels(_title, rotation=90)
    ax.set_ylim(0,0.3)
    ax.axhline(y=0.10,color="r", lw=1) #優位水準　10以上で受容/正規分布を有しているとみなせる
    
#     ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
#     ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
    plt.show()
    return

# %%
def tmp2(N,c,yy=2018):
    _df,_title=[],[]
    for p in _path:
        kwyword = os.path.basename(p).split(".")[0].split("_")[1]
        df = get_stock(kwyword,st=datetime(yy,1,1,0,0),ed=datetime(yy+1,1,1,0,0))
        _df.append(df)
        title = convert_roma(kwyword)
        _title.append(title)
#     plot_multi(_df,c,_title=_title)
#     plot_vola(_df,c,_title=_title,isPrint=True)
#     plot_corr(_df,c,_title=_title) #相関係数を求める
    plot_shapiro(_df,c,_title,isPrint=True)
    return
    
        
tmp2(N=10,c="log_diff",yy=2015)
# Out:
# toyota -> W = 0.9644004106521606 | p-values = 9.158252396446187e-06
# hondagiken -> W = 0.9542376399040222 | p-values = 5.6349529131694e-07
# nissanjidousha -> W = 0.9719661474227905 | p-values = 9.601738565834239e-05
# densoo -> W = 0.9468857645988464 | p-values = 9.227095887354153e-08
# aishin -> W = 0.9565377235412598 | p-values = 1.0260545195706072e-06
# suzuki -> W = 0.9663807153701782 | p-values = 1.651666207180824e-05
# matsuda -> W = 0.9715984463691711 | p-values = 8.510805491823703e-05
# SUBARU -> W = 0.9550575017929077 | p-values = 6.96340123340633e-07
# burijisuton -> W = 0.9699071645736694 | p-values = 4.930798604618758e-05
# toyoda -> W = 0.9765950441360474 | p-values = 0.00046664290130138397
# isuゞ -> W = 0.9887682199478149 | p-values = 0.054384466260671616
# hino -> W = 0.9752745032310486 | p-values = 0.0002936124801635742
# kawasakijuukougyou -> W = 0.9786328673362732 | p-values = 0.000973448739387095
# yamaha -> W = 0.982815146446228 | p-values = 0.004770601633936167
# mitsubishijidousha -> W = 0.9683868288993835 | p-values = 3.055243723792955e-05
# toyota -> W = 0.9136864542961121 | p-values = 1.1297137531007806e-10
# sumitomo -> W = 0.9334716200828552 | p-values = 4.802599651299033e-09
# toyoda -> W = 0.9874691367149353 | p-values = 0.03157857805490494
# mitsui -> W = 0.9492655992507935 | p-values = 1.630146044817593e-07
# NOK -> W = 0.974791407585144 | p-values = 0.0002484558499418199
# yokohamagomu -> W = 0.9501359462738037 | p-values = 2.0150331181412184e-07
# futaba -> W = 0.9721403121948242 | p-values = 0.0001016866008285433
# toukai -> W = 0.9686650633811951 | p-values = 3.33215321006719e-05
# sumitomo -> W = 0.9671446084976196 | p-values = 2.083045183098875e-05
# mitsubishi -> W = 0.885026216506958 | p-values = 1.2012966576352424e-12
# shimano -> W = 0.9842806458473206 | p-values = 0.008542013354599476
# nissanshatai -> W = 0.9873085021972656 | p-values = 0.0295343529433012
# tei・esu -> W = 0.9664216041564941 | p-values = 1.6722106011002325e-05
# TOYO TIRE -> W = 0.9117733836174011 | p-values = 8.105115884005087e-11
# KYB -> W = 0.9385948777198792 | p-values = 1.4174706741698628e-08

# %%
#自己相関の確認　->Ljung-box の検定
from statsmodels.stats.diagnostic import acorr_ljungbox

def plot_LjungBox(_df,c,_title,isPrint=False):
    #　自己相関の有無の検定
#     帰無仮説[自己相関なし]　--
#     p-value　大：　自己相関なし
#     p-values　小：　自己相関の可能性
    f,ax = plt.subplots(figsize=(20,8))
    
    _df2=[]
    _w,_p=[],[]
    for j,(df,title) in enumerate(zip(_df,_title)):
        
        lbvalues, pvalues = acorr_ljungbox(df[c].values, lags=50)
#         _w.append(W)
#         _p.append(p)
        
        if isPrint:  
            p= pvalues[0]
            print(title,f"-> Ljung-Box | p-values = {p}")
            
#     ax.legend()
    ax.bar(np.arange(len(_df)), _p)
    ax.set_xlim(0,len(_df))
    ax.set_xticks(np.arange(len(_df)))
    ax.set_xticklabels(_title, rotation=90)
    ax.set_ylim(0,0.3)
    ax.axhline(y=0.10,color="r", lw=1) #優位水準　10以上で受容/正規分布を有しているとみなせる
    
#     ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
#     ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
    plt.show()
    return

# %%
# shapiro(norm.rvs(size=100000))
#　ノンパラメトリック検定についての解説
# https://plaza.umin.ac.jp/~health-stat/wpsystem/wp-content/uploads/2017/01/chapter6_slide.pdf

#---　看護・保健系大学院生の為の統計学習サイト　->　表示を行ったもの
# https://plaza.umin.ac.jp/~health-stat/about/
#パラメトリックー>　正規分布性を評価して行う検定について
def tmp3(_key,st,ed):
    _df,_title=[],[]
    
    n_com = len(_key)
    f,ax=plt.subplots(2,2,figsize=(18,2*4))
    for i,key in enumerate(_key):
        title=convert_roma(key)
#         kwyword = os.path.basename(p).split(".")[0].split("_")[1]
        df = get_stock(key,st=st,ed=ed)
        ax[0,i].plot(df["close"])
        ax[0,i].set_title(title)
        
        ax[1,i].plot(df["log_diff"])
        ax[1,i].axhline(y=0,lw=1, color="r")
    
    ax=ax.T
    plt.show()
    return

def tmp4(_key,st,ed):
    # 収益率の時間依存を確認する為のscatter
    _df,_title=[],[]
    lag1,lag2=1,5
    n_com = len(_key)
    f,ax=plt.subplots(2,2,figsize=(18,18))
    for i,key in enumerate(_key):
        title=convert_roma(key)
#         kwyword = os.path.basename(p).split(".")[0].split("_")[1]
        df = get_stock(key,st=st,ed=ed)
        ax[0,i].scatter(df["log_diff"],df["log_diff"].shift(lag1),color="r")
        ax[0,i].plot(df["log_diff"],df["log_diff"],color="k", lw=1)
        ax[0,i].set_title(f"{title}({lag1})")
        
        ax[1,i].scatter(df["log_diff"],df["log_diff"].shift(lag2),color="r")
        ax[1,i].plot(df["log_diff"],df["log_diff"],color="k", lw=1)
        ax[1,i].set_title(f"{title}({lag2})")
    
    ax=ax.T
    plt.show()
    return

st,ed=datetime(2019,1,1,0,0),datetime(2019,7,1,0,0) 
_key = ["トヨタ自動車","ＫＹＢ"]
# tmp3(_key,st,ed)
tmp4(_key,st,ed)

# %%
def tmp2(N,c,yy=2018):
    _df,_title=[],[]
    for p in _path:
        kwyword = os.path.basename(p).split(".")[0].split("_")[1]
        df = get_stock(kwyword,st=datetime(yy,1,1,0,0),ed=datetime(yy+1,1,1,0,0))
        _df.append(df)
        title = convert_roma(kwyword)
        _title.append(title)
#     plot_multi(_df,c,_title=_title)
#     plot_vola(_df,c,_title=_title,isPrint=True)
#     plot_corr(_df,c,_title=_title) #相関係数を求める
#     plot_shapiro(_df,c,_title,isPrint=True)
    plot_LjungBox(_df,c,_title,isPrint=True)
    return
tmp2(10,"log_diff",yy=2018)
# Out:
# toyota -> Ljung-Box | p-values = 0.890305472938294
# hondagiken -> Ljung-Box | p-values = 0.4625030178319425
# nissanjidousha -> Ljung-Box | p-values = 0.05418288112422517
# densoo -> Ljung-Box | p-values = 0.8478420059537227
# aishin -> Ljung-Box | p-values = 0.15444839228821697
# suzuki -> Ljung-Box | p-values = 0.22809083774292216
# matsuda -> Ljung-Box | p-values = 0.49421493881869305
# SUBARU -> Ljung-Box | p-values = 0.8159829165220578
# burijisuton -> Ljung-Box | p-values = 0.6787986817197587
# toyoda -> Ljung-Box | p-values = 0.9599053470249828
# isuゞ -> Ljung-Box | p-values = 0.3792690087216871
# hino -> Ljung-Box | p-values = 0.6432575132107443
# kawasakijuukougyou -> Ljung-Box | p-values = 0.15687581873836118
# yamaha -> Ljung-Box | p-values = 0.21698238504556525
# mitsubishijidousha -> Ljung-Box | p-values = 0.9029308390260036
# toyota -> Ljung-Box | p-values = 0.5280387493586981
# sumitomo -> Ljung-Box | p-values = 0.8331121546809481
# toyoda -> Ljung-Box | p-values = 0.6413845871031647
# mitsui -> Ljung-Box | p-values = 0.00013972759957743937
# NOK -> Ljung-Box | p-values = 0.05501854959610425
# yokohamagomu -> Ljung-Box | p-values = 0.5143438121036369
# futaba -> Ljung-Box | p-values = 0.6604059741637556
# toukai -> Ljung-Box | p-values = 0.8928057460193066
# sumitomo -> Ljung-Box | p-values = 0.08807974050225026
# mitsubishi -> Ljung-Box | p-values = 0.006543764721670171
# shimano -> Ljung-Box | p-values = 0.5329558556156855
# nissanshatai -> Ljung-Box | p-values = 0.0329448030921724
# tei・esu -> Ljung-Box | p-values = 0.4485962675912416
# TOYO TIRE -> Ljung-Box | p-values = 0.775384364057346
# KYB -> Ljung-Box | p-values = 5.235142323856749e-05
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-191-0b39d38e6c4b> in <module>
#      13     plot_LjungBox(_df,c,_title,isPrint=True)
#      14     return
# ---> 15 tmp2(10,"log_diff",yy=2018)
#
# <ipython-input-191-0b39d38e6c4b> in tmp2(N, c, yy)
#      11 #     plot_corr(_df,c,_title=_title) #相関係数を求める
#      12 #     plot_shapiro(_df,c,_title,isPrint=True)
# ---> 13     plot_LjungBox(_df,c,_title,isPrint=True)
#      14     return
#      15 tmp2(10,"log_diff",yy=2018)
#
# <ipython-input-188-e3328c179ada> in plot_LjungBox(_df, c, _title, isPrint)
#      22
#      23 #     ax.legend()
# ---> 24     ax.bar(np.arange(len(_df)), _p)
#      25     ax.set_xlim(0,len(_df))
#      26     ax.set_xticks(np.arange(len(_df)))
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2428                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2429
# -> 2430         x, height, width, y, linewidth = np.broadcast_arrays(
#    2431             # Make args iterable too.
#    2432             np.atleast_1d(x), height, width, y, linewidth)
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/.conda/envs/sori_torch/lib/python3.8/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     256     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     257
# --> 258     shape = _broadcast_shape(*args)
#     259
#     260     if all(array.shape == shape for array in args):
#
# ~/.conda/envs/sori_torch/lib/python3.8/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     187     # use the old-iterator because np.nditer does not handle size 0 arrays
#     188     # consistently
# --> 189     b = np.broadcast(*args[:32])
#     190     # unfortunately, it cannot handle 32 or more arguments directly
#     191     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
#自己回帰　AR(1)　モデルの作成方法
